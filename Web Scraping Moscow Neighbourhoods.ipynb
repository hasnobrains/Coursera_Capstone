# %% [markdown]
# #### URL's with Moscow Neighbouthoods data

# %%
mosopen_url = 'http://mosopen.ru/regions'
wikipedia_url = 'https://ru.wikipedia.org/wiki/Районы_и_поселения_Москвы'

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page
import pandas as pd

# %% [markdown]
# #### Scraping neighbourhoods locations

# %%
mosopen_data  = requests.get(mosopen_url).text 
soup = BeautifulSoup(mosopen_data, 'html5lib')
table = soup.find('table', {'class': 'regions_list'}) 

df = pd.DataFrame(columns=['Name', 'Latitude', 'Longitude', 'Area', 'Population', 'Density', 'URL', 'Borders_URL'])

for a in table.find_all('a'):
    href = a.get('href')
    name = a.get_text()
    df = df.append({'Name':name, 'URL':href}, ignore_index=True)

df
# Out:
#               Name Latitude Longitude Area Population Density  \
# 0    Академический      NaN       NaN  NaN        NaN     NaN
# 1     Алексеевский      NaN       NaN  NaN        NaN     NaN
# 2     Алтуфьевский      NaN       NaN  NaN        NaN     NaN
# 3            Арбат      NaN       NaN  NaN        NaN     NaN
# 4         Аэропорт      NaN       NaN  NaN        NaN     NaN
# ..             ...      ...       ...  ...        ...     ...
# 120         Щукино      NaN       NaN  NaN        NaN     NaN
# 121   Южнопортовый      NaN       NaN  NaN        NaN     NaN
# 122       Якиманка      NaN       NaN  NaN        NaN     NaN
# 123    Ярославский      NaN       NaN  NaN        NaN     NaN
# 124        Ясенево      NaN       NaN  NaN        NaN     NaN
#
#                                          URL Borders_URL
# 0    http://mosopen.ru/region/akademicheskij         NaN
# 1      http://mosopen.ru/region/alekseevskij         NaN
# 2       http://mosopen.ru/region/altufevskij         NaN
# 3             http://mosopen.ru/region/arbat         NaN
# 4          http://mosopen.ru/region/aeroport         NaN
# ..                                       ...         ...
# 120       http://mosopen.ru/region/shchukino         NaN
# 121  http://mosopen.ru/region/yuzhnoportovyj         NaN
# 122       http://mosopen.ru/region/yakimanka         NaN
# 123    http://mosopen.ru/region/yaroslavskij         NaN
# 124        http://mosopen.ru/region/yasenevo         NaN
#
# [125 rows x 8 columns]

# %% [markdown]
# #### For each location go to URL and scrape neighbourhood coordinates

# %%
import re

# %%
for name, url in list(df[['Name','URL']].itertuples(index=False)):
    print('Processing {} neighbourhood ...'.format(name))
    data  = requests.get(url).text 
    soup = BeautifulSoup(data, 'html5lib')

    pattern = re.compile(r'var center = new YMaps.GeoPoint\((.*),(.*)\);')

    script = soup.find('script', text=pattern)

    match = pattern.search(script.text)
    longitude = match.group(1)
    latitude = match.group(2)

    df.loc[df['Name'] == name, 'Latitude'] = latitude
    df.loc[df['Name'] == name, 'Longitude'] = longitude

    pattern = re.compile(r'var ml = new YMaps.YMapsML\("(.*)"\);')
    script = soup.find('script', text=pattern)

    match = pattern.search(script.text)
    borders_url = match.group(1)

    df.loc[df['Name'] == name, 'Borders_URL'] = borders_url
    
df
# Out:
# Processing Академический neighbourhood ...
# Processing Алексеевский neighbourhood ...
# Processing Алтуфьевский neighbourhood ...
# Processing Арбат neighbourhood ...
# Processing Аэропорт neighbourhood ...
# Processing Бабушкинский neighbourhood ...
# Processing Басманный neighbourhood ...
# Processing Беговой neighbourhood ...
# Processing Бескудниковский neighbourhood ...
# Processing Бибирево neighbourhood ...
# Processing Бирюлёво Восточное neighbourhood ...
# Processing Бирюлёво Западное neighbourhood ...
# Processing Богородское neighbourhood ...
# Processing Братеево neighbourhood ...
# Processing Бутово Северное neighbourhood ...
# Processing Бутово Южное neighbourhood ...
# Processing Бутырский neighbourhood ...
# Processing Вешняки neighbourhood ...
# Processing Внуково neighbourhood ...
# Processing Войковский neighbourhood ...
# Processing Восточный neighbourhood ...
# Processing Выхино-Жулебино neighbourhood ...
# Processing Гагаринский neighbourhood ...
# Processing Головинский neighbourhood ...
# Processing Гольяново neighbourhood ...
# Processing Даниловский neighbourhood ...
# Processing Дегунино Восточное neighbourhood ...
# Processing Дегунино Западное neighbourhood ...
# Processing Дмитровский neighbourhood ...
# Processing Донской neighbourhood ...
# Processing Дорогомилово neighbourhood ...
# Processing Замоскворечье neighbourhood ...
# Processing Зюзино neighbourhood ...
# Processing Зябликово neighbourhood ...
# Processing Ивановское neighbourhood ...
# Processing Измайлово Восточное neighbourhood ...
# Processing Измайлово neighbourhood ...
# Processing Измайлово Северное neighbourhood ...
# Processing Капотня neighbourhood ...
# Processing Коньково neighbourhood ...
# Processing Коптево neighbourhood ...
# Processing Косино-Ухтомский neighbourhood ...
# Processing Котловка neighbourhood ...
# Processing Красносельский neighbourhood ...
# Processing Крылатское neighbourhood ...
# Processing Крюково neighbourhood ...
# Processing Кузьминки neighbourhood ...
# Processing Кунцево neighbourhood ...
# Processing Куркино neighbourhood ...
# Processing Левобережный neighbourhood ...
# Processing Лефортово neighbourhood ...
# Processing Лианозово neighbourhood ...
# Processing Ломоносовский neighbourhood ...
# Processing Лосиноостровский neighbourhood ...
# Processing Люблино neighbourhood ...
# Processing Марфино neighbourhood ...
# Processing Марьина роща neighbourhood ...
# Processing Марьино neighbourhood ...
# Processing Матушкино neighbourhood ...
# Processing Медведково Северное neighbourhood ...
# Processing Медведково Южное neighbourhood ...
# Processing Метрогородок neighbourhood ...
# Processing Мещанский neighbourhood ...
# Processing Митино neighbourhood ...
# Processing Можайский neighbourhood ...
# Processing Молжаниновский neighbourhood ...
# Processing Москворечье-Сабурово neighbourhood ...
# Processing Нагатино-Садовники neighbourhood ...
# Processing Нагатинский затон neighbourhood ...
# Processing Нагорный neighbourhood ...
# Processing Некрасовка neighbourhood ...
# Processing Нижегородский neighbourhood ...
# Processing Ново-Переделкино neighbourhood ...
# Processing Новогиреево neighbourhood ...
# Processing Новокосино neighbourhood ...
# Processing Обручевский neighbourhood ...
# Processing Орехово-Борисово Северное neighbourhood ...
# Processing Орехово-Борисово Южное neighbourhood ...
# Processing Останкинский neighbourhood ...
# Processing Отрадное neighbourhood ...
# Processing Очаково-Матвеевское neighbourhood ...
# Processing Перово neighbourhood ...
# Processing Печатники neighbourhood ...
# Processing Покровское-Стрешнево neighbourhood ...
# Processing Преображенское neighbourhood ...
# Processing Пресненский neighbourhood ...
# Processing Проспект Вернадского neighbourhood ...
# Processing Раменки neighbourhood ...
# Processing Ростокино neighbourhood ...
# Processing Рязанский neighbourhood ...
# Processing Савёлки neighbourhood ...
# Processing Савёловский neighbourhood ...
# Processing Свиблово neighbourhood ...
# Processing Северный neighbourhood ...
# Processing Силино neighbourhood ...
# Processing Сокол neighbourhood ...
# Processing Соколиная гора neighbourhood ...
# Processing Сокольники neighbourhood ...
# Processing Солнцево neighbourhood ...
# Processing Старое Крюково neighbourhood ...
# Processing Строгино neighbourhood ...
# Processing Таганский neighbourhood ...
# Processing Тверской neighbourhood ...
# Processing Текстильщики neighbourhood ...
# Processing Тёплый Стан neighbourhood ...
# Processing Тимирязевский neighbourhood ...
# Processing Тропарёво-Никулино neighbourhood ...
# Processing Тушино Северное neighbourhood ...
# Processing Тушино Южное neighbourhood ...
# Processing Филёвский парк neighbourhood ...
# Processing Фили-Давыдково neighbourhood ...
# Processing Хамовники neighbourhood ...
# Processing Ховрино neighbourhood ...
# Processing Хорошёво-Мневники neighbourhood ...
# Processing Хорошёвский neighbourhood ...
# Processing Царицыно neighbourhood ...
# Processing Черёмушки neighbourhood ...
# Processing Чертаново Северное neighbourhood ...
# Processing Чертаново Центральное neighbourhood ...
# Processing Чертаново Южное neighbourhood ...
# Processing Щукино neighbourhood ...
# Processing Южнопортовый neighbourhood ...
# Processing Якиманка neighbourhood ...
# Processing Ярославский neighbourhood ...
# Processing Ясенево neighbourhood ...
#               Name   Latitude  Longitude Area Population Density  \
# 0    Академический     55.685     37.578  NaN        NaN     NaN
# 1     Алексеевский  55.811314  37.648773  NaN        NaN     NaN
# 2     Алтуфьевский    55.8783     37.584  NaN        NaN     NaN
# 3            Арбат   55.75092  37.592189  NaN        NaN     NaN
# 4         Аэропорт     55.801      37.54  NaN        NaN     NaN
# ..             ...        ...        ...  ...        ...     ...
# 120         Щукино     55.801     37.471  NaN        NaN     NaN
# 121   Южнопортовый     55.715     37.675  NaN        NaN     NaN
# 122       Якиманка  55.730832   37.61075  NaN        NaN     NaN
# 123    Ярославский      55.86    37.6925  NaN        NaN     NaN
# 124        Ясенево     55.615  37.544403  NaN        NaN     NaN
#
#                                          URL  \
# 0    http://mosopen.ru/region/akademicheskij
# 1      http://mosopen.ru/region/alekseevskij
# 2       http://mosopen.ru/region/altufevskij
# 3             http://mosopen.ru/region/arbat
# 4          http://mosopen.ru/region/aeroport
# ..                                       ...
# 120       http://mosopen.ru/region/shchukino
# 121  http://mosopen.ru/region/yuzhnoportovyj
# 122       http://mosopen.ru/region/yakimanka
# 123    http://mosopen.ru/region/yaroslavskij
# 124        http://mosopen.ru/region/yasenevo
#
#                                            Borders_URL
# 0    http://mosopen.ru/public/ymapsml.php?p=region/...
# 1    http://mosopen.ru/public/ymapsml.php?p=region/...
# 2    http://mosopen.ru/public/ymapsml.php?p=region/...
# 3    http://mosopen.ru/public/ymapsml.php?p=region/...
# 4    http://mosopen.ru/public/ymapsml.php?p=region/...
# ..                                                 ...
# 120  http://mosopen.ru/public/ymapsml.php?p=region/...
# 121  http://mosopen.ru/public/ymapsml.php?p=region/...
# 122  http://mosopen.ru/public/ymapsml.php?p=region/...
# 123  http://mosopen.ru/public/ymapsml.php?p=region/...
# 124  http://mosopen.ru/public/ymapsml.php?p=region/...
#
# [125 rows x 8 columns]

# %% [markdown]
# #### For each neigbourhoods scrape borders and save to corresponding csv

# %%
import lxml

# %%
for name, url in list(df[['Name', 'Borders_URL']].itertuples(index=False)):
    print('Processing {} neighbourhood borders ...'.format(name))
    data  = requests.get(url).text 
    soup = BeautifulSoup(data, 'lxml')

    with open(name + ' borders.csv', 'w') as f:
        f.write('Latitude,Longitude\n')
    
        for row in soup.find_all('gml:pos'):
            longitude, latitude = row.text.split(' ')
            f.write('{},{}\n'.format(latitude, longitude))
# Out:
# Processing Академический neighbourhood borders ...
# Processing Алексеевский neighbourhood borders ...
# Processing Алтуфьевский neighbourhood borders ...
# Processing Арбат neighbourhood borders ...
# Processing Аэропорт neighbourhood borders ...
# Processing Бабушкинский neighbourhood borders ...
# Processing Басманный neighbourhood borders ...
# Processing Беговой neighbourhood borders ...
# Processing Бескудниковский neighbourhood borders ...
# Processing Бибирево neighbourhood borders ...
# Processing Бирюлёво Восточное neighbourhood borders ...
# Processing Бирюлёво Западное neighbourhood borders ...
# Processing Богородское neighbourhood borders ...
# Processing Братеево neighbourhood borders ...
# Processing Бутово Северное neighbourhood borders ...
# Processing Бутово Южное neighbourhood borders ...
# Processing Бутырский neighbourhood borders ...
# Processing Вешняки neighbourhood borders ...
# Processing Внуково neighbourhood borders ...
# Processing Войковский neighbourhood borders ...
# Processing Восточный neighbourhood borders ...
# Processing Выхино-Жулебино neighbourhood borders ...
# Processing Гагаринский neighbourhood borders ...
# Processing Головинский neighbourhood borders ...
# Processing Гольяново neighbourhood borders ...
# Processing Даниловский neighbourhood borders ...
# Processing Дегунино Восточное neighbourhood borders ...
# Processing Дегунино Западное neighbourhood borders ...
# Processing Дмитровский neighbourhood borders ...
# Processing Донской neighbourhood borders ...
# Processing Дорогомилово neighbourhood borders ...
# Processing Замоскворечье neighbourhood borders ...
# Processing Зюзино neighbourhood borders ...
# Processing Зябликово neighbourhood borders ...
# Processing Ивановское neighbourhood borders ...
# Processing Измайлово Восточное neighbourhood borders ...
# Processing Измайлово neighbourhood borders ...
# Processing Измайлово Северное neighbourhood borders ...
# Processing Капотня neighbourhood borders ...
# Processing Коньково neighbourhood borders ...
# Processing Коптево neighbourhood borders ...
# Processing Косино-Ухтомский neighbourhood borders ...
# Processing Котловка neighbourhood borders ...
# Processing Красносельский neighbourhood borders ...
# Processing Крылатское neighbourhood borders ...
# Processing Крюково neighbourhood borders ...
# Processing Кузьминки neighbourhood borders ...
# Processing Кунцево neighbourhood borders ...
# Processing Куркино neighbourhood borders ...
# Processing Левобережный neighbourhood borders ...
# Processing Лефортово neighbourhood borders ...
# Processing Лианозово neighbourhood borders ...
# Processing Ломоносовский neighbourhood borders ...
# Processing Лосиноостровский neighbourhood borders ...
# Processing Люблино neighbourhood borders ...
# Processing Марфино neighbourhood borders ...
# Processing Марьина роща neighbourhood borders ...
# Processing Марьино neighbourhood borders ...
# Processing Матушкино neighbourhood borders ...
# Processing Медведково Северное neighbourhood borders ...
# Processing Медведково Южное neighbourhood borders ...
# Processing Метрогородок neighbourhood borders ...
# Processing Мещанский neighbourhood borders ...
# Processing Митино neighbourhood borders ...
# Processing Можайский neighbourhood borders ...
# Processing Молжаниновский neighbourhood borders ...
# Processing Москворечье-Сабурово neighbourhood borders ...
# Processing Нагатино-Садовники neighbourhood borders ...
# Processing Нагатинский затон neighbourhood borders ...
# Processing Нагорный neighbourhood borders ...
# Processing Некрасовка neighbourhood borders ...
# Processing Нижегородский neighbourhood borders ...
# Processing Ново-Переделкино neighbourhood borders ...
# Processing Новогиреево neighbourhood borders ...
# Processing Новокосино neighbourhood borders ...
# Processing Обручевский neighbourhood borders ...
# Processing Орехово-Борисово Северное neighbourhood borders ...
# Processing Орехово-Борисово Южное neighbourhood borders ...
# Processing Останкинский neighbourhood borders ...
# Processing Отрадное neighbourhood borders ...
# Processing Очаково-Матвеевское neighbourhood borders ...
# Processing Перово neighbourhood borders ...
# Processing Печатники neighbourhood borders ...
# Processing Покровское-Стрешнево neighbourhood borders ...
# Processing Преображенское neighbourhood borders ...
# Processing Пресненский neighbourhood borders ...
# Processing Проспект Вернадского neighbourhood borders ...
# Processing Раменки neighbourhood borders ...
# Processing Ростокино neighbourhood borders ...
# Processing Рязанский neighbourhood borders ...
# Processing Савёлки neighbourhood borders ...
# Processing Савёловский neighbourhood borders ...
# Processing Свиблово neighbourhood borders ...
# Processing Северный neighbourhood borders ...
# Processing Силино neighbourhood borders ...
# Processing Сокол neighbourhood borders ...
# Processing Соколиная гора neighbourhood borders ...
# Processing Сокольники neighbourhood borders ...
# Processing Солнцево neighbourhood borders ...
# Processing Старое Крюково neighbourhood borders ...
# Processing Строгино neighbourhood borders ...
# Processing Таганский neighbourhood borders ...
# Processing Тверской neighbourhood borders ...
# Processing Текстильщики neighbourhood borders ...
# Processing Тёплый Стан neighbourhood borders ...
# Processing Тимирязевский neighbourhood borders ...
# Processing Тропарёво-Никулино neighbourhood borders ...
# Processing Тушино Северное neighbourhood borders ...
# Processing Тушино Южное neighbourhood borders ...
# Processing Филёвский парк neighbourhood borders ...
# Processing Фили-Давыдково neighbourhood borders ...
# Processing Хамовники neighbourhood borders ...
# Processing Ховрино neighbourhood borders ...
# Processing Хорошёво-Мневники neighbourhood borders ...
# Processing Хорошёвский neighbourhood borders ...
# Processing Царицыно neighbourhood borders ...
# Processing Черёмушки neighbourhood borders ...
# Processing Чертаново Северное neighbourhood borders ...
# Processing Чертаново Центральное neighbourhood borders ...
# Processing Чертаново Южное neighbourhood borders ...
# Processing Щукино neighbourhood borders ...
# Processing Южнопортовый neighbourhood borders ...
# Processing Якиманка neighbourhood borders ...
# Processing Ярославский neighbourhood borders ...
# Processing Ясенево neighbourhood borders ...

# %%
df.loc[df['Name'] == 'Хорошёво-Мневники', 'Name'] = 'Хорошёво-Мнёвники'
df.loc[df['Name'] == 'Марьина роща', 'Name'] = 'Марьина Роща'
df.loc[df['Name'] == 'Нагатинский затон', 'Name'] = 'Нагатинский Затон'
df.loc[df['Name'] == 'Соколиная гора', 'Name'] = 'Соколиная Гора'
df.loc[df['Name'] == 'Филёвский парк', 'Name'] = 'Филёвский Парк'

# %% [markdown]
# #### For each neigbourhood scrap area, population and density from Wikipedia

# %%
wikipedia_data  = requests.get(wikipedia_url).text 
soup = BeautifulSoup(wikipedia_data, 'html5lib')

table = soup.find('table')

for row in table.find_all('tr'):
    col = row.find_all('td')
    if (col != []):
        name = col[3].getText().strip()
        x = name.split(' ')
        if len(x) > 1 and (x[0] == 'Северное' or x[0] == 'Южное' or x[0] == 'Восточное' or x[0] == 'Западное'): 
            name = x[1] + ' ' + x[0]
        area = float(col[6].getText().replace(' ', '').replace(',','.'))
        population = int(col[7].getText().replace(' ','').replace(u'\xa0','')[1:])
        density = float(col[8].getText().replace(' ', ''))
        
        print('[{}] [{}] [{}] [{}]'.format(name, area, population, density))

        df.loc[df['Name'] == name, 'Area'] = area
        df.loc[df['Name'] == name, 'Population'] = population
        df.loc[df['Name'] == name, 'Density'] = density

df
# Out:
# [Академический] [5.83] [110459] [18946.66]
# [Алексеевский] [5.29] [80449] [15207.75]
# [Алтуфьевский] [3.25] [57601] [17723.38]
# [Арбат] [2.11] [36107] [17112.32]
# [Аэропорт] [4.58] [79413] [17339.08]
# [Бабушкинский] [5.07] [88607] [17476.73]
# [Басманный] [8.37] [110329] [13181.48]
# [Беговой] [5.56] [42634] [7667.99]
# [Бескудниковский] [3.3] [79607] [24123.33]
# [Бибирево] [6.45] [160248] [24844.65]
# [Бирюлёво Восточное] [14.77] [155196] [10507.52]
# [Бирюлёво Западное] [8.51] [88573] [10408.11]
# [Богородское] [10.24] [110044] [10746.48]
# [Братеево] [7.63] [109732] [14381.65]
# [Бутырский] [5.04] [71721] [14230.36]
# [Вешняки] [10.72] [121972] [11377.99]
# [Внуково] [17.42] [25764] [1478.99]
# [Войковский] [6.61] [70623] [10684.27]
# [Дегунино Восточное] [3.77] [98923] [26239.52]
# [Измайлово Восточное] [3.85] [77931] [20241.82]
# [Восточный] [3.14] [13698] [4362.42]
# [Выхино-Жулебино] [14.97] [224783] [15015.56]
# [Московский, поселение[Прим. 11]] [40.6] [63007] [1551.9]
# [Мосрентген, поселение[Прим. 12]] [6.41] [20571] [3209.2]
# [Новофёдоровское, поселение[Прим. 13]] [156.75] [7399] [47.2]
# [Первомайское, поселение[Прим. 14]] [118.94] [9224] [77.55]
# [Роговское, поселение[Прим. 15]] [175.95] [4107] [23.34]
# [Рязановское, поселение[Прим. 16]] [41.41] [21703] [524.1]
# [Сосенское, поселение[Прим. 17]] [67.07] [33418] [498.26]
# [Троицк, поселение[Прим. 18]] [16.33] [61097] [3741.4]
# [Филимонковское, поселение[Прим. 19]] [35.77] [8041] [224.8]
# [Щаповское, поселение[Прим. 20]] [86.06] [9584] [111.36]
# [Щербинка, поселение[Прим. 21]] [7.62] [53974] [7083.2]
#               Name   Latitude  Longitude   Area Population  Density  \
# 0    Академический     55.685     37.578   5.83     110459  18946.7
# 1     Алексеевский  55.811314  37.648773   5.29      80449  15207.8
# 2     Алтуфьевский    55.8783     37.584   3.25      57601  17723.4
# 3            Арбат   55.75092  37.592189   2.11      36107  17112.3
# 4         Аэропорт     55.801      37.54   4.58      79413  17339.1
# ..             ...        ...        ...    ...        ...      ...
# 120         Щукино     55.801     37.471   7.69     111207  14461.2
# 121   Южнопортовый     55.715     37.675   4.53      74756  16502.4
# 122       Якиманка  55.730832   37.61075    4.8      27754  5782.08
# 123    Ярославский      55.86    37.6925   7.99      98134  12282.1
# 124        Ясенево     55.615  37.544403  25.37     178089  7019.67
#
#                                          URL  \
# 0    http://mosopen.ru/region/akademicheskij
# 1      http://mosopen.ru/region/alekseevskij
# 2       http://mosopen.ru/region/altufevskij
# 3             http://mosopen.ru/region/arbat
# 4          http://mosopen.ru/region/aeroport
# ..                                       ...
# 120       http://mosopen.ru/region/shchukino
# 121  http://mosopen.ru/region/yuzhnoportovyj
# 122       http://mosopen.ru/region/yakimanka
# 123    http://mosopen.ru/region/yaroslavskij
# 124        http://mosopen.ru/region/yasenevo
#
#                                            Borders_URL
# 0    http://mosopen.ru/public/ymapsml.php?p=region/...
# 1    http://mosopen.ru/public/ymapsml.php?p=region/...
# 2    http://mosopen.ru/public/ymapsml.php?p=region/...
# 3    http://mosopen.ru/public/ymapsml.php?p=region/...
# 4    http://mosopen.ru/public/ymapsml.php?p=region/...
# ..                                                 ...
# 120  http://mosopen.ru/public/ymapsml.php?p=region/...
# 121  http://mosopen.ru/public/ymapsml.php?p=region/...
# 122  http://mosopen.ru/public/ymapsml.php?p=region/...
# 123  http://mosopen.ru/public/ymapsml.php?p=region/...
# 124  http://mosopen.ru/public/ymapsml.php?p=region/...
#
# [125 rows x 8 columns]

# %% [markdown]
# #### Save dataframe to csv

# %%
df.to_csv('moscow_neighbourhoods.csv', index=False)

# %%
# Out:
# Empty DataFrame
# Columns: [Name, Latitude, Longitude, Area, Population, Density, URL, Borders_URL]
# Index: []
