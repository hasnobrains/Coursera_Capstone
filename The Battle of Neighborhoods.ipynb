# %%
import requests

# %%
# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# Out:
# Requirement already satisfied: geopy in /Users/hasnobrains/opt/anaconda3/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/hasnobrains/opt/anaconda3/lib/python3.8/site-packages (from geopy) (1.50)

# %%
CLIENT_ID = '32BYLFVM1M21ELZ41ZGIU0SB4CYOZNGF5UT2ZXOBUUATJSPD' # your Foursquare ID
CLIENT_SECRET = '2QJ3N0LYHCDO41JRRMF44Y5JGIIA0SHVFLEBXJJ4SMF3UBPF' # your Foursquare Secret
ACCESS_TOKEN = 'USYTRHBRVGFD5F102GON4PMIXKB5AMIIJS0XET1505QRZD4K' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30

# %%
#address = '102 North End Ave, New York, NY'
address = 'Moscow Russia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
search_query = 'Irish'
radius = 500

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=32BYLFVM1M21ELZ41ZGIU0SB4CYOZNGF5UT2ZXOBUUATJSPD&client_secret=2QJ3N0LYHCDO41JRRMF44Y5JGIIA0SHVFLEBXJJ4SMF3UBPF&ll=55.7504461,37.6174943&oauth_token=USYTRHBRVGFD5F102GON4PMIXKB5AMIIJS0XET1505QRZD4K&v=20180604&query=Irish'

# %%
results = requests.get(url).json()
# assign relevant part of JSON to venues
venues = results['response']['venues']

import pandas as pd
# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe
# Out:
#                           id                              name  \
# 0   5746d9fc498e2cda924b0867            Sean O'Neill Irish Pub
# 1   4bc467b02a89ef3bb733f688                Mollie's Irish Pub
# 2   5719255a498ea14d559c99d4        Paddy's Irish Pub & Eatery
# 3   5b1d66b9cbcdee002c82ad9e                 Harat’s Irish Pub
# 4   573ee5af498e246fea7a03a9              Blacksmith Irish Pub
# 5   54a700c5498e66aeb0fe902f                         Irish pub
# 6   55f2abc9498edccca4bff5a0     Silver's Irish Pub (Сильверс)
# 7   5d470090349edc0008b97720                     Irish Harbour
# 8   5266a5ef11d2f135de05968a                      Irish Tattoo
# 9   4b8c06a9f964a52055b932e3                        Eat & Talk
# 10  56e5c70c498eaca0d1b2095c                   Dagda Irish Pub
# 11  50002096e4b0bcfe22992e31                       Iris hostel
# 12  4bbb70b4add2a593e480cdb6  Салли О`Брайенс / Sally O`Briens
# 13  5c812995ad1789002c69ffc6                    Irish Mist Pub
# 14  57613801498ecbe793d02a69                      OʼDonoghueʼs
# 15  5ab68b75dd84427a40aac2ad              Blacksmith Irish Pub
# 16  4f329b0ce4b0e6be3c4ff12d                Irish Dance School
# 17  55956a95498e20cc5f0f29cf                  Clever Irish Pub
# 18  50f047d6e4b095b3ef6ad9f3                  Family Irish Pub
# 19  52d2e59c498e111395204d8a                        Irish Luck
# 20  4f3f37f5e4b0bc95aef6d06e          Irish Dance Maria Singal
# 21  588f74e045005e04ead03491                          IrisHome
# 22  4dbb2c136e815ab0de64b06b             Ирландский паб О'Хара
# 23  4c8b1af56418a1438096e6ce                     The Irish Bar
# 24  4ba12183f964a520cb9a37e3                    Molly Malone's
# 25  5ffd880e082d7424254d84b3                 Crowley Irish Pub
# 26  608c45b699949845cbf9932f                 Harat’s Irish pub
# 27  52ff7467498e521d476c3162           Irish Pub Kimberli Land
# 28  4c095a33340720a147a58493                      Boondock Pub
# 29  55e8bb62498e3ae4839e48ee         Irish Bar  "on The 15-th"
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 1   [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 2   [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 3   [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 4   [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 5   [{'id': '4e0e22f5a56208c4ea9a85a0', 'name': 'D...  v-1623096220    False
# 6   [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 7   [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 8   [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1623096220    False
# 9   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1623096220    False
# 10  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 11  [{'id': '4bf58dd8d48988d1ee931735', 'name': 'H...  v-1623096220    False
# 12  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 13  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 14  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 15  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 16                                                 []  v-1623096220    False
# 17  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 18  [{'id': '4e0e22f5a56208c4ea9a85a0', 'name': 'D...  v-1623096220    False
# 19  [{'id': '4bf58dd8d48988d111951735', 'name': 'J...  v-1623096220    False
# 20  [{'id': '5032792091d4c4b30a586d5c', 'name': 'C...  v-1623096220    False
# 21  [{'id': '4bf58dd8d48988d1ff941735', 'name': 'M...  v-1623096220    False
# 22  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 23  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 24  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 25  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 26  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 27  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 28  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
# 29  [{'id': '52e81612bcbc57f1066b7a06', 'name': 'I...  v-1623096220    False
#
#                    location.address  location.lat  location.lng  \
# 0            ул. Кузнецкий Мост, 11     55.762183     37.621950
# 1         Мясницкая ул., 13, стр. 3     55.762382     37.634547
# 2                   Лесная ул., 1/2     55.777170     37.585133
# 3                Ярцевская 22, Стр1     55.738767     37.412772
# 4              ул. Бутырский Вал, 5     55.778080     37.584505
# 5                               NaN     55.761428     37.614571
# 6                ул. Машкова, 28/20     55.764588     37.655143
# 7           18 Новослободская улица     55.782138     37.599276
# 8   ул. Юных Ленинцев, 105, корп. 2     55.700064     37.782327
# 9                    Моховая ул., 7     55.753084     37.610991
# 10   Колокольников пер., 22, стр. 5     55.767974     37.628987
# 11                              NaN     55.772363     37.598841
# 12         ул. Большая Полянка, 1/3     55.741845     37.616069
# 13                   ул. Шухова, 19     55.716557     37.609910
# 14                Пятницкая ул., 29     55.740794     37.629131
# 15                           Streat     55.708969     37.653201
# 16     Комсомольский Проспект 46 К1     55.721634     37.567871
# 17     Дубининская ул., 57, корп. 2     55.720355     37.635292
# 18           Электрический Переулок     55.771715     37.575449
# 19                              NaN     55.716571     37.688514
# 20           ул. Ивантеевская, 13К1     55.817649     37.726435
# 21                              NaN     55.762895     37.606924
# 22        ул. Фридриха Энгельса, 20     55.772247     37.682291
# 23            Шереметьево F / SVO F     55.967091     37.415532
# 24       Старая Басманная ул., 38/2     55.769245     37.669204
# 25        Преображенская площадь, 8     55.794786     37.712857
# 26                              NaN     55.839565     37.487867
# 27                              NaN     55.646790     37.596501
# 28    Большая Сухаревская пл., 14/7     55.771883     37.636757
# 29                              NaN     55.801561     37.819393
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 55.762182818509, ...               1336
# 1   [{'label': 'display', 'lat': 55.7623818314243,...               1704
# 2   [{'label': 'display', 'lat': 55.77716978966838...               3599
# 3   [{'label': 'display', 'lat': 55.73876677670736...              12893
# 4   [{'label': 'display', 'lat': 55.77808048736582...               3705
# 5   [{'label': 'display', 'lat': 55.76142780023196...               1236
# 6   [{'label': 'display', 'lat': 55.76458790384263...               2835
# 7   [{'label': 'display', 'lat': 55.782138, 'lng':...               3707
# 8   [{'label': 'display', 'lat': 55.700064, 'lng':...              11757
# 9   [{'label': 'display', 'lat': 55.75308389760644...                502
# 10  [{'label': 'display', 'lat': 55.76797436854495...               2079
# 11  [{'label': 'display', 'lat': 55.77236256297193...               2705
# 12  [{'label': 'display', 'lat': 55.74184533430200...                961
# 13  [{'label': 'display', 'lat': 55.716557, 'lng':...               3802
# 14  [{'label': 'display', 'lat': 55.74079423811565...               1298
# 15  [{'label': 'display', 'lat': 55.70896947868243...               5131
# 16  [{'label': 'display', 'lat': 55.72163367232677...               4467
# 17  [{'label': 'display', 'lat': 55.72035492930725...               3530
# 18  [{'label': 'display', 'lat': 55.771715, 'lng':...               3541
# 19  [{'label': 'display', 'lat': 55.71657130393007...               5833
# 20  [{'label': 'display', 'lat': 55.81764911864213...              10122
# 21  [{'label': 'display', 'lat': 55.762895, 'lng':...               1535
# 22  [{'label': 'display', 'lat': 55.77224691245128...               4728
# 23  [{'label': 'display', 'lat': 55.96709138011823...              27218
# 24  [{'label': 'display', 'lat': 55.76924508616475...               3856
# 25  [{'label': 'display', 'lat': 55.7947857942284,...               7747
# 26  [{'label': 'display', 'lat': 55.839565, 'lng':...              12814
# 27  [{'label': 'display', 'lat': 55.64679042620477...              11613
# 28  [{'label': 'display', 'lat': 55.77188298406150...               2673
# 29  [{'label': 'display', 'lat': 55.80156075705825...              13862
#
#    location.postalCode location.cc location.city location.state  \
# 0               107031          RU        Москва         Москва
# 1                  NaN          RU        Москва         Москва
# 2                  NaN          RU        Москва         Москва
# 3               121351          RU        Москва         Москва
# 4               125047          RU        Москва         Москва
# 5                  NaN          RU           NaN            NaN
# 6               105064          RU        Москва         Москва
# 7               127030          RU        Москва         Москва
# 8                  NaN          RU        Москва         Москва
# 9               125009          RU        Москва         Москва
# 10              107045          RU        Москва         Москва
# 11                 NaN          RU           NaN            NaN
# 12                 NaN          RU        Москва         Москва
# 13              115162          RU        Москва         Москва
# 14              115035          RU        Москва         Москва
# 15              115280          RU        Москва         Москва
# 16                 NaN          RU        Москва         Москва
# 17                 NaN          RU        Москва         Москва
# 18                 NaN          RU        Москва         Москва
# 19                 NaN          RU           NaN            NaN
# 20                 NaN          RU        Москва         Москва
# 21                 NaN          RU           NaN            NaN
# 22              105005          RU        Москва         Москва
# 23              141400          RU         Химки         Москва
# 24              105066          RU        Москва         Москва
# 25                 NaN          RU        Москва         Москва
# 26              125212          RU        Москва         Москва
# 27                 NaN          RU           NaN            NaN
# 28              107045          RU        Москва         Москва
# 29                 NaN          RU           NaN            NaN
#
#    location.country                          location.formattedAddress  \
# 0            Россия           [ул. Кузнецкий Мост, 11, 107031, Москва]
# 1            Россия                [Мясницкая ул., 13, стр. 3, Москва]
# 2            Россия                          [Лесная ул., 1/2, Москва]
# 3            Россия               [Ярцевская 22, Стр1, 121351, Москва]
# 4            Россия             [ул. Бутырский Вал, 5, 125047, Москва]
# 5            Россия                                                NaN
# 6            Россия  [ул. Машкова, 28/20 (Садовая-Черногрязская ул....
# 7            Россия          [18 Новослободская улица, 127030, Москва]
# 8            Россия          [ул. Юных Ленинцев, 105, корп. 2, Москва]
# 9            Россия                   [Моховая ул., 7, 125009, Москва]
# 10           Россия   [Колокольников пер., 22, стр. 5, 107045, Москва]
# 11           Россия                                                NaN
# 12           Россия                 [ул. Большая Полянка, 1/3, Москва]
# 13           Россия                   [ул. Шухова, 19, 115162, Москва]
# 14           Россия  [Пятницкая ул., 29 (Климентовский пер.), 11503...
# 15           Россия                           [Streat, 115280, Москва]
# 16           Россия             [Комсомольский Проспект 46 К1, Москва]
# 17           Россия             [Дубининская ул., 57, корп. 2, Москва]
# 18           Россия                   [Электрический Переулок, Москва]
# 19           Россия                                                NaN
# 20           Россия                   [ул. Ивантеевская, 13К1, Москва]
# 21           Россия                                                NaN
# 22           Россия        [ул. Фридриха Энгельса, 20, 105005, Москва]
# 23           Россия             [Шереметьево F / SVO F, 141400, Химки]
# 24           Россия       [Старая Басманная ул., 38/2, 105066, Москва]
# 25           Россия                [Преображенская площадь, 8, Москва]
# 26           Россия                                   [125212, Москва]
# 27           Россия                                                NaN
# 28           Россия  [Большая Сухаревская пл., 14/7 (Ананьевский пе...
# 29           Россия                                                NaN
#
#          location.crossStreet location.neighborhood venuePage.id
# 0                         NaN                   NaN          NaN
# 1                         NaN                   NaN          NaN
# 2                         NaN                   NaN          NaN
# 3                         NaN                   NaN          NaN
# 4                         NaN                   NaN          NaN
# 5                         NaN                   NaN          NaN
# 6   Садовая-Черногрязская ул.                   NaN          NaN
# 7                         NaN                   NaN          NaN
# 8                         NaN                   NaN          NaN
# 9                         NaN                   NaN          NaN
# 10                        NaN     Мещанский, Москва    170303650
# 11                        NaN                   NaN          NaN
# 12                        NaN                   NaN          NaN
# 13                        NaN           Даниловский          NaN
# 14         Климентовский пер.                   NaN          NaN
# 15                        NaN                   NaN          NaN
# 16                        NaN                   NaN          NaN
# 17                        NaN                   NaN          NaN
# 18                        NaN                   NaN          NaN
# 19                        NaN                   NaN          NaN
# 20                        NaN                   NaN          NaN
# 21                        NaN                   NaN          NaN
# 22                        NaN                   NaN     34902818
# 23                        NaN                   NaN          NaN
# 24                        NaN                   NaN          NaN
# 25                        NaN                   NaN          NaN
# 26                        NaN                   NaN          NaN
# 27                        NaN                   NaN          NaN
# 28           Ананьевский пер.                   NaN          NaN
# 29                        NaN                   NaN          NaN
